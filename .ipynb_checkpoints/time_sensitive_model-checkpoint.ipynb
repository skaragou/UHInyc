# %%
import cmdstanpy
import pandas as pd
import numpy as np
from cmdstanpy import cmdstan_path, CmdStanModel
import random
from tqdm import tqdm
import matplotlib.pyplot as plt
import seaborn as sns
import json
import scipy.stats as stats
import patsy

MODEL_PATH = 'time_model_2.stan'

sns.set_style("darkgrid", {"axes.facecolor": ".9"})

# %%
temps = pd.read_csv('data/Hyperlocal_Temperature_Monitoring.csv')
temps.head()
# Out:
#   Sensor.ID    AirTemp         Day  Hour   Latitude  Longitude  Year  \
# 0  Bk-BR_01  71.189000  06/15/2018     1  40.666205  -73.91691  2018
# 1  Bk-BR_01  70.243333  06/15/2018     2  40.666205  -73.91691  2018
# 2  Bk-BR_01  69.392667  06/15/2018     3  40.666205  -73.91691  2018
# 3  Bk-BR_01  68.263167  06/15/2018     4  40.666205  -73.91691  2018
# 4  Bk-BR_01  67.114000  06/15/2018     5  40.666205  -73.91691  2018
#
#   Install.Type   Borough ntacode
# 0  Street Tree  Brooklyn    BK81
# 1  Street Tree  Brooklyn    BK81
# 2  Street Tree  Brooklyn    BK81
# 3  Street Tree  Brooklyn    BK81
# 4  Street Tree  Brooklyn    BK81

# %%
covariates = pd.read_csv('data/temp3.csv').round(8)
covariates2 = pd.read_csv('data/temp_1.csv').round(8)
covariates = covariates.merge(covariates2)
covariates['mean_fa_ratio'] = covariates['mean_fa_ratio'].fillna(0)
temps = temps.drop(index=np.where(temps['AirTemp'].isna())[0])
data = temps.merge(covariates, how='outer', on=['Latitude','Longitude'])

# %%
data
# Out:
#         Sensor.ID    AirTemp         Day  Hour   Latitude  Longitude  Year  \
# 0        Bk-BR_01  71.189000  06/15/2018     1  40.666205  -73.91691  2018
# 1        Bk-BR_01  70.243333  06/15/2018     2  40.666205  -73.91691  2018
# 2        Bk-BR_01  69.392667  06/15/2018     3  40.666205  -73.91691  2018
# 3        Bk-BR_01  68.263167  06/15/2018     4  40.666205  -73.91691  2018
# 4        Bk-BR_01  67.114000  06/15/2018     5  40.666205  -73.91691  2018
# ...           ...        ...         ...   ...        ...        ...   ...
# 2085438   Q-CH_26  78.346667  09/07/2019    15  40.699578  -73.73876  2019
# 2085439   Q-CH_26  79.517167  09/07/2019    16  40.699578  -73.73876  2019
# 2085440   Q-CH_26  77.203667  09/07/2019    17  40.699578  -73.73876  2019
# 2085441   Q-CH_26  75.696000  09/07/2019    18  40.699578  -73.73876  2019
# 2085442   Q-CH_26  72.359000  09/07/2019    19  40.699578  -73.73876  2019
#
#         Install.Type   Borough ntacode  num_build500  mean_fa_ratio  \
# 0        Street Tree  Brooklyn    BK81            30       1.430347
# 1        Street Tree  Brooklyn    BK81            30       1.430347
# 2        Street Tree  Brooklyn    BK81            30       1.430347
# 3        Street Tree  Brooklyn    BK81            30       1.430347
# 4        Street Tree  Brooklyn    BK81            30       1.430347
# ...              ...       ...     ...           ...            ...
# 2085438   Light Pole    Queens    QN33            28       1.319975
# 2085439   Light Pole    Queens    QN33            28       1.319975
# 2085440   Light Pole    Queens    QN33            28       1.319975
# 2085441   Light Pole    Queens    QN33            28       1.319975
# 2085442   Light Pole    Queens    QN33            28       1.319975
#
#          min_distance_park  num_trees_50m
# 0               638.624047              2
# 1               638.624047              2
# 2               638.624047              2
# 3               638.624047              2
# 4               638.624047              2
# ...                    ...            ...
# 2085438        1255.416584              0
# 2085439        1255.416584              0
# 2085440        1255.416584              0
# 2085441        1255.416584              0
# 2085442        1255.416584              0
#
# [2085443 rows x 14 columns]

# %%
data['month'] = pd.to_datetime(data['Day']).dt.month

# %%
data = pd.get_dummies(data,columns=['month'])

# %%
g = data.groupby(['Sensor.ID','Day'])

# %%
H = 24
K = 4
N = len(g.indices)

y = []#np.zeros([N,H])
X = []#np.zeros([N,K])
# INVESTIGATE DATA
i = 0

for k,_ in tqdm(g.indices.items()):
    sub_group = g.get_group(k)
    if sub_group['AirTemp'].shape[0] == H:
        y.append(sub_group['AirTemp'])
        covariates = sub_group[['num_build500','mean_fa_ratio','min_distance_park','num_trees_50m','month_6','month_7','month_8', 'month_9','month_10']].iloc[0].values
        X.append(covariates)

y = np.array(y)
X = np.array(X)
# Out:
#   0%|                                                   | 2/87029 [00:00<23:54, 60.65it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /var/folders/95/hjbq_fhx1x94_j9lsth52q0m0000gn/T/ipykernel_29341/11735817.py in <module>
#      12     if sub_group['AirTemp'].shape[0] == H:
#      13         y.append(sub_group['AirTemp'])
# ---> 14         covariates = sub_group[['num_build500','mean_fa_ratio','min_distance_park','num_trees_50m','month']].iloc[0].values
#      15         X.append(covariates)
#      16
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3462             if is_iterator(key):
#    3463                 key = list(key)
# -> 3464             indexer = self.loc._get_listlike_indexer(key, axis=1)[1]
#    3465
#    3466         # take() does not accept boolean indexers
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis)
#    1312             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1313
# -> 1314         self._validate_read_indexer(keyarr, indexer, axis)
#    1315
#    1316         if needs_i8_conversion(ax.dtype) or isinstance(
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis)
#    1375
#    1376             not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 1377             raise KeyError(f"{not_found} not in index")
#    1378
#    1379
#
# KeyError: "['month'] not in index"

# %%
l = random.sample(range(y.shape[0]),100)
for i in l:
    sns.lineplot(x=range(24),y=y[i,:])

# %%
N = y.shape[0]
X_new_size = 5000
# X_size = N - X_new_size
X_size = 10000
shuff_idx = random.shuffle(list(range(N)))
shuff_y, shuff_X = y[shuff_idx,:][0], X[shuff_idx,:][0]
beta_mean = np.random.normal(size=X.shape[1])
beta_sd = np.random.uniform(size=X.shape[1])

# %%
d = {'N': N, 'M': X_size, 'H': H, 'K': K, 'X': shuff_X, 'y': shuff_y,'beta_mean': beta_mean,'beta_sd': beta_sd,'y_cov':shuff_y[:X_size,:].T}

# %%
model = CmdStanModel(stan_file=MODEL_PATH)
# Out:
# INFO:cmdstanpy:found newer exe file, not recompiling
# INFO:cmdstanpy:compiled model file: /Users/sotiriskaragounis/git/UHInyc/time_model_2

# %%
bern_vb = model.variational(data=d)
# Out:
# INFO:cmdstanpy:start chain 1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/95/hjbq_fhx1x94_j9lsth52q0m0000gn/T/ipykernel_29341/330711396.py in <module>
# ----> 1 bern_vb = model.variational(data=d)
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/site-packages/cmdstanpy/model.py in variational(self, data, seed, inits, output_dir, sig_figs, save_diagnostics, save_profile, algorithm, iter, grad_samples, elbo_samples, eta, adapt_engaged, adapt_iter, tol_rel_obj, eval_elbo, output_samples, require_converged, refresh)
#    1153             dummy_chain_id = 0
#    1154             runset = RunSet(args=args, chains=1)
# -> 1155             self._run_cmdstan(runset, dummy_chain_id)
#    1156
#    1157         # treat failure to converge as failure
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/site-packages/cmdstanpy/model.py in _run_cmdstan(self, runset, idx, pbar)
#    1212             if pbar:
#    1213                 stdout_pbar = self._read_progress(proc, pbar, idx)
# -> 1214             stdout, stderr = proc.communicate()
#    1215             if pbar:
#    1216                 stdout = stdout_pbar + stdout
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/subprocess.py in communicate(self, input, timeout)
#    1132
#    1133             try:
# -> 1134                 stdout, stderr = self._communicate(input, endtime, timeout)
#    1135             except KeyboardInterrupt:
#    1136                 # https://bugs.python.org/issue25942
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/subprocess.py in _communicate(self, input, endtime, orig_timeout)
#    1977                             'failed to raise TimeoutExpired.')
#    1978
# -> 1979                     ready = selector.select(timeout)
#    1980                     self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1981
#
# ~/opt/anaconda3/envs/cmdstan/lib/python3.9/selectors.py in select(self, timeout)
#     414         ready = []
#     415         try:
# --> 416             fd_event_list = self._selector.poll(timeout)
#     417         except InterruptedError:
#     418             return ready
#
# KeyboardInterrupt:

# %% [markdown]
# ## MCMC

# %%
b = bern_vb.stan_variable(var='beta')
for i in range(4):
    sns.lineplot(x=range(24),y=b[:,i])

# %%
y_sims = bern_vb.stan_variable(var='y_rep')
b = bern_vb.stan_variable(var='beta')

# %%
sns.lineplot(x=range(24),y=shuff_y[1,:],label='true')
sns.lineplot(x=range(24),y=y_sims[1,:])
# Out:
# <AxesSubplot:>

# %%
def check(simulated_data,y,agg_func,function_name):
    agg_data = agg_func(simulated_data,axis=1)
    ax = sns.displot(agg_data)
    ax.fig.suptitle(function_name)
    ax.axes[0][0].axvline(x = agg_func(y), color='red', linewidth=1,label='Original Data')
    plt.legend()
    plt.show()

# %%
n = 3000
y = shuffled_data['AirTemp'][:X_size] 
simulated_data = y_sims[:n]

check(simulated_data,y,np.mean,'Mean')
check(simulated_data,y,np.min,'Min')
check(simulated_data,y,np.max,'Max')
check(simulated_data,y,np.var,'Variance')
check(simulated_data,y,np.median,'Median')

# %%
from patsy import dmatrix

B = interpolate.BSpline

# %%
mu = np.zeros(5)
cov = np.eye(5)
r = np.random.multivariate_normal(mu,cov) 
sns.lineplot(x=range(5),y=r)
# Out:
# <AxesSubplot:>

# %%
n = 100
mu = np.zeros(n)
cov = np.eye(n)

cov = cov_off_axis(n,cov)
cov = cov_exp(n,mu,cov)

r = np.random.multivariate_normal(mu,cov) 
sns.lineplot(x=range(n),y=r[:])
# Out:
# <AxesSubplot:>

# %%
def cov_off_axis(n,cov):
    for i in range(n):
        if i != n - 1:
            cov[i,i+1] = .5
        if i != 0:
            cov[i,i-1] = .5
    return cov
        
def cov_exp(n,mu,cov):
    l = list(range(n))
    for i in range(n):
        for j in range(n):
            cov[i,j] = np.exp(-(np.abs(l[i] - l[j]))*1/n)
    return cov

# %%
cov = bern_vb.stan_variable(var='Sigma')
sns.heatmap(cov)
# Out:
# <AxesSubplot:>
